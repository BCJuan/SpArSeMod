# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Reading results .csv

# %% [markdown]
# First, we open the csv

# %%
data = pd.read_csv("./experiment_stages.csv", index_col=0)

# %%
data
# Out:
#      arm_name metric_name      mean  sem  trial_index
# 0         0_0    accuracy  0.863764  0.0            0
# 1         0_0      weight  0.759929  0.0            0
# 2         0_0         ram  0.742178  0.0            0
# 3         0_0     latency  0.700812  0.0            0
# 4         1_0    accuracy  0.856055  0.0            1
# ...       ...         ...       ...  ...          ...
# 3439    898_0     latency  0.386514  0.0          898
# 3440    899_0    accuracy  0.693567  0.0          899
# 3441    899_0      weight  0.645198  0.0          899
# 3442    899_0         ram  0.597882  0.0          899
# 3443    899_0     latency  0.560919  0.0          899
#
# [3444 rows x 5 columns]

# %% [markdown]
# ## Reoder by arm

# %% [markdown]
# We need to reorder it to be able to group different performances in one row and by arm

# %%
data_use = data.pivot(columns='metric_name', values='mean',
                         index='arm_name')

# %%
data_use
# Out:
# metric_name  accuracy   latency       ram    weight
# arm_name
# 0_0          0.863764  0.700812  0.742178  0.759929
# 100_0        0.887413  0.731766  0.731707  0.742589
# 101_0        0.745633  0.600187  0.640419  0.662944
# 102_0        0.780813  0.877629  0.815546  0.819566
# 103_0        0.839836  0.865126  0.759096  0.772022
# ...               ...       ...       ...       ...
# 96_0         0.856954  0.628227  0.714687  0.716730
# 97_0         0.814327  0.815786  0.720382  0.740246
# 98_0         0.779552  0.835525  0.795593  0.799492
# 99_0         0.929388  0.870108  0.762296  0.778889
# 9_0          0.874026  0.622833  0.688345  0.692745
#
# [861 rows x 4 columns]

# %% [markdown]
# ## DeStandardize

# %% [markdown]
# As we can see results are grouped by arm but we have a problem, they are still in relative values. SpArSeMoD uses sntardardizers internally to place the performance metrics in the same range (approx [0, 1]). To ungroup them we must know the standardization procedure, which is
#
# $$
# standardized value = \frac{\log(real value)}{\log(standardization value)}
# $$
#
# where the standardization value depends on the metric.
#
# + Model Size: $10^8$
# + Working memory $10^8$
# + Latency $10^4$
#
# Hence to recover the original value we have to isolate the real value in the last equation and we will obtain real values for all these metrics. Accuracy has no standardization. With this we will recover the number of parameters.
#
# Then depending that we consider if 8 bit data types or 32-float, we will use a different conversion.
#
# In the case or model size ('weight') and working memory ('ram'), we can proceed to suppose that they are 8-bit parameters and convert them to kilobytes, by dividing by 1024.

# %%
data_use['real_weight'] = np.exp(data_use['weight']*np.log(10**8))*8/8/1024
data_use['real_ram'] = np.exp(data_use['ram']*np.log(10**8))*8/8/1024
data_use['real_latency'] = np.exp(data_use['latency']*np.log(10**4) + 1)

# %%
data_use
# Out:
# metric_name  accuracy   latency       ram    weight  real_weight     real_ram  \
# arm_name
# 0_0          0.863764  0.700812  0.742178  0.759929  1172.554687   845.519531
# 100_0        0.887413  0.731766  0.731707  0.742589   851.944336   697.201172
# 101_0        0.745633  0.600187  0.640419  0.662944   196.448242   129.734375
# 102_0        0.780813  0.877629  0.815546  0.819566  3517.472656  3266.403320
# 103_0        0.839836  0.865126  0.759096  0.772022  1465.121094  1154.699219
# ...               ...       ...       ...       ...          ...          ...
# 96_0         0.856954  0.628227  0.714687  0.716730   529.102539   509.564453
# 97_0         0.814327  0.815786  0.720382  0.740246   815.957031   565.923828
# 98_0         0.779552  0.835525  0.795593  0.799492  2430.161133  2261.730469
# 99_0         0.929388  0.870108  0.762296  0.778889  1662.679688  1224.797852
# 9_0          0.874026  0.622833  0.688345  0.692745   340.141602   313.660156
#
# metric_name  real_latency
# arm_name
# 0_0           1727.989978
# 100_0         2298.038992
# 101_0          683.976792
# 102_0         8806.658072
# 103_0         7848.745137
# ...                   ...
# 96_0           885.527774
# 97_0          4982.418885
# 98_0          5975.801082
# 99_0          8217.233077
# 9_0            842.609128
#
# [861 rows x 7 columns]

# %% [markdown]
# ## Pareto frontier

# %% [markdown]
# However, now we have all the result most of them do not interest us, since we only want the Pareto front. For this we have thw following function, that returns the pareto front

# %%
from sparsemod.heir import is_pareto_efficient

# %%
pareto_mask = is_pareto_efficient(data_use.values)
pareto_arms = data_use.index[pareto_mask].values

# %% [markdown]
# We then sort the vlaues, for example, by accuracy

# %%
data_use[pareto_mask].sort_values(by ='accuracy')
# Out:
# metric_name  accuracy   latency       ram    weight  real_weight   real_ram  \
# arm_name
# 749_0        0.441566  0.477598  0.608714  0.632693   112.523438  72.345703
# 830_0        0.458480  0.568465  0.593087  0.636163   119.952148  54.250000
# 864_0        0.460964  0.525769  0.591832  0.630761   108.589844  53.009766
# 851_0        0.462113  0.498104  0.590432  0.610507    74.774414  51.660156
# 872_0        0.465986  0.329839  0.567794  0.557612    28.222656  34.044922
# 813_0        0.488876  0.319337  0.568937  0.565051    32.367188  34.769531
# 751_0        0.514050  0.439655  0.567196  0.613807    79.460937  33.671875
# 750_0        0.524590  0.405708  0.563421  0.587740    49.161133  31.410156
# 890_0        0.524661  0.323127  0.578966  0.548809    23.998047  41.824219
# 762_0        0.524954  0.297555  0.578966  0.550886    24.933594  41.824219
# 820_0        0.525258  0.396666  0.566249  0.591023    52.225586  33.089844
# 662_0        0.527652  0.231885  0.522573  0.496681     9.186523  14.800781
# 814_0        0.669006  0.127201  0.546106  0.559091    29.001953  22.832031
# 805_0        0.685306  0.202677  0.527641  0.511524    12.075195  16.249023
# 761_0        0.792398  0.057969  0.518749  0.500416     9.840820  13.793945
#
# metric_name  real_latency
# arm_name
# 749_0          221.148774
# 830_0          510.688296
# 864_0          344.643410
# 851_0          267.123143
# 872_0           56.708660
# 813_0           51.480656
# 751_0          155.924893
# 750_0          114.058460
# 890_0           53.309244
# 762_0           42.122631
# 820_0          104.944571
# 662_0           23.005669
# 814_0            8.771963
# 805_0           17.579298
# 761_0            4.636268

# %% [markdown]
# Where we can see that the best model has a total accuracy of accuracy = (1- error) = 1 - 0.441 = 0.559, a model sie of 112KB in 8-bit vlaues, a RAM of 72 KB and a latency of 221 ms.

# %% [markdown]
# ### Pareto Front and evolution

# %% [markdown]
# We can visualize the frontier obtained by Sparse

# %%
plt.figure(figsize=(10,6))
cm = plt.cm.get_cmap('RdYlBu_r')
sc = plt.scatter(1-data_use[pareto_mask].sort_values(by ='accuracy')['accuracy'],
         data_use[pareto_mask].sort_values(by ='accuracy')['real_weight'],
           c=data_use[pareto_mask].sort_values(by ='accuracy')['real_ram'], s=40, cmap=cm)



cb = plt.colorbar(sc)
cb.ax.tick_params(labelsize=20)
cb.ax.set_ylabel(" RAM (KB)", fontsize=25)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.ylabel("Model Size (KB)", fontsize=25, fontfamily='serif')
plt.xlabel("Accuracy", fontsize=25, fontfamily='serif')

# %% [markdown]
# as well as the evolution

# %%
data_use['arm'] = data_use.index
data_use['arm'] = data_use['arm'].apply(lambda x: int(x.split("_")[0]))
data_use.sort_values(by='arm')

plt.figure(figsize=(10,6))
cm = plt.cm.get_cmap('RdYlBu_r')
sc = plt.scatter(1 - data_use.sort_values(by='arm')['accuracy'],
         data_use.sort_values(by='arm')['real_weight'],
           c=range(len(data_use.sort_values(by='arm'))), s=40, cmap=cm)



cb = plt.colorbar(sc)
cb.ax.tick_params(labelsize=20)
cb.ax.set_ylabel(" Evaluation Step", fontsize=25, fontfamily='serif')
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.ylabel("Model Size (KB)", fontsize=25, fontfamily='serif')
plt.xlabel("Accuracy", fontsize=25, fontfamily='serif')

# %% [markdown]
# # Inspecting an arm

# %% [markdown]
# In the performance lookup we saw that the bet arm was `749_0`. As we want the specific configuration to build the network we need to observe the specific parameters. For this we have to load a Sparse experiment. in `./cnn_cost_example/read_experiment/` a function has been built for that purpose

# %%
from read_experiment import load_experiment
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-da4dd615c0b4> in <module>
# ----> 1 from read_experiment import load_experiment
#
# ModuleNotFoundError: No module named 'read_experiment'

# %%
exp, data = load_experiment(data_folder="./data/data_cost/")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-14-3ed45ef47788> in <module>
# ----> 1 exp, data = load_experiment()
#
# ~/Documents/projects/sparse/SpArSe/examples/cnn_cost_example/read_experiment.py in load_experiment(data_folder)
#      19     filterwarnings(action="ignore", category=UserWarning)
#      20
# ---> 21     datasets, n_classes = prepare_cost(folder=data_folder, image=True)
#      22     search_space = search_space()
#      23     quant_params = None
#
# ~/Documents/projects/sparse/SpArSe/examples/cnn_cost_example/load_data.py in prepare_cost(folder, test_subjects, image)
#     254     # turns y labels into numbers; # generate dataset according to y labels stratification
#     255     # scaling, o ne hot encoding
# --> 256     x_data, y_data, extra = build_cost(folder=folder)
#     257     x_train, y_train, _, x_val, y_val, _, x_test, y_test, _ = divide_cost(
#     258         x_data, y_data, extra, test_subjects=test_subjects
#
# ~/Documents/projects/sparse/SpArSe/examples/cnn_cost_example/load_data.py in build_cost(folder)
#     105     y = []
#     106     extra = {}
# --> 107     for i, arxiv in enumerate(listdir(folder)):
#     108         X.append(load(path.join(folder, arxiv)))
#     109         meta = arxiv.split("_")
#
# FileNotFoundError: [Errno 2] No such file or directory: '../data/data_cost/files'
